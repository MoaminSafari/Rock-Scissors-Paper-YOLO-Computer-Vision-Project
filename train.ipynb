# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
drive_path = 'drive/MyDrive/Vision/Project'
dataset_dir_path = drive_path + "/dataset"
dataset_path = dataset_dir_path + "/data.yaml"
result_path = drive_path + "/results"
pretrained_model = drive_path + "/yolo11n.pt"
experiment_name = "rsp"

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.6/913.6 kB 13.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# !yolo settings runs_dir=$drive_path datasets_dir=$dataset_dir_path
model = YOLO(pretrained_model)
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "drive/MyDrive/Vision/Project/dataset",
#   "weights_dir": "weights",
#   "runs_dir": "drive/MyDrive/Vision/Project",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
# !yolo task=detect mode=train epochs=40 batch=32 plots=True save=True device=0 model=$pretrained_model data=$dataset_path imgsz=640 project=$result_path name=$experiment_name
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
best_model = YOLO(f"{result_path}/{experiment_name}/weights/best.pt")
best_model.export(format="onnx")
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.30GHz)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'drive/MyDrive/Vision/Project/results/rsp/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 1.3s, saved as 'drive/MyDrive/Vision/Project/results/rsp/weights/best.onnx' (10.1 MB)
#
# Export complete (2.1s)
# Results saved to /content/drive/MyDrive/Vision/Project/results/rsp/weights
# Predict:         yolo predict task=detect model=drive/MyDrive/Vision/Project/results/rsp/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=drive/MyDrive/Vision/Project/results/rsp/weights/best.onnx imgsz=640 data=drive/MyDrive/Vision/Project/dataset/data.yaml
# Visualize:       https://netron.app
# ...
